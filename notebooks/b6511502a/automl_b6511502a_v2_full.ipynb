# %% [markdown]
# # B-6511502A — AutoML v2 FULL (treino limpo)
#
# Treino completo (task `583d0560`, 6165 trials, janelas 3/20). **Melhor: LSTM/baseline/p99.9 →
# 100% de detecção @ 0,87% FP** — supera o re-threshold da task antiga (78%). SAVE_PLOTS off (inline).

# %%
import sys; from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from clearml import Task
PROJECT_ROOT=next((p for p in [Path.cwd(),*Path.cwd().parents] if (p/'pyproject.toml').exists()),Path.cwd())
sys.path.insert(0,str(PROJECT_ROOT/'src'))
from transpetro_modelos.config import EQUIPMENT_CONFIGS
from transpetro_modelos.data.loading import load_equipment_data
from transpetro_modelos.data.preprocessing import run_preprocessing

# %%
EQUIPMENT_ID='B-6511502A'; AUTOML_TASK_ID='583d0560d4db449c9b96dc557604d154'
EVENT_TS_F1=pd.Timestamp('2023-05-15 00:00'); EVENT_LABEL_F1='Falha'
PREFAILURE_DAYS=3; NORMAL_END_DAYS=20
KEY_SENSORS=['VIB. MANCAL RADIAL MOT LA 90° VE-50B', 'VIB. MANCAL RADIAL MOT LA 0° VE-51B', 'CORRENTE ELÉTRICA DO MOTOR']
SAVE_PLOTS=False

# %%
def load_scores(task_id):
    task=Task.get_task(task_id=task_id)
    s=task.artifacts['best_full_scores'].get(); s.index=pd.to_datetime(s.index); s=s.sort_index()
    s['is_anomaly']=s['is_anomaly'].astype(bool)
    res=task.artifacts['automl_results'].get() if 'automl_results' in task.artifacts else None
    bt=task.artifacts['best_trial'].get() if 'best_trial' in task.artifacts else None
    return s[['reconstruction_error','is_anomaly']],res,bt,task
def persistence_filter(flags,k,n):
    if k==1 and n==1: return flags.astype(bool)
    return (flags.astype(int).rolling(window=n,min_periods=n).sum()>=k).fillna(False).astype(bool)
def load_plot_base(eq):
    cfg=EQUIPMENT_CONFIGS[eq]; df_raw=load_equipment_data(eq,from_clearml=False)
    df_base,_,_=run_preprocessing(df_raw,cfg.pre_split_steps,fitted_scaler=None) if cfg.pre_split_steps else (df_raw,None,None)
    df_base=df_base.sort_index(); df_base.index=pd.to_datetime(df_base.index); return df_base,cfg
def model_info_str(bt):
    t=bt['trial']; r=bt['results']
    return (f"Modelo AutoML: {str(t.get('model')).upper()} / {t.get('preset')} / p{t.get('threshold_percentile')} / "
            f"debounce {t.get('debounce_consecutive')}  ·  pré-falha {r.get('prefailure_alert_rate',0):.0%} @ FP {r.get('normal_alert_rate',0):.1%}")
def _slug(t): return ''.join(c if c.isalnum() else '_' for c in str(t)).strip('_').lower()
def plot_separated(df_window,scores_window,sensors,threshold,k,n,event_ts,event_label,prefailure_days,
                   title_prefix,tag,threshold_label='Limiar',model_info='',shade=False,save=False,outdir=None,dpi=200):
    plt.style.use('seaborn-v0_8-whitegrid')
    flags=persistence_filter(scores_window['reconstruction_error']>threshold,k=k,n=n); anom_idx=scores_window.index[flags]
    for col in list(sensors)+['__score__']:
        fig,ax=plt.subplots(figsize=(14,3.2))
        if col=='__score__':
            y=scores_window['reconstruction_error']; ax.plot(y.index,y,color='purple',lw=0.9,alpha=0.6,label='Score')
            ax.axhline(threshold,color='red',ls='--',lw=1.2,label=threshold_label)
            if len(anom_idx): ax.scatter(anom_idx,y.reindex(anom_idx),s=28,color='red',zorder=4,label='Alerta')
            ax.set_ylabel('Score'); ttl='Score de Anomalia'
        else:
            if col not in df_window.columns: plt.close(fig); continue
            ax.plot(df_window.index,df_window[col],color='steelblue',lw=1.0,alpha=0.85,label=col)
            av=df_window[col].reindex(anom_idx).dropna()
            if not av.empty: ax.scatter(av.index,av.values,s=28,color='red',zorder=4,label='Anomalia')
            ax.set_ylabel(col,fontsize=9); ttl=col
        ax.axvline(event_ts,color='orange',ls='--',lw=1.4,label=event_label); ax.set_xlabel('Tempo'); ax.legend(loc='upper left',fontsize=8)
        ax.set_title(f'{title_prefix} | {ttl}',fontsize=12,fontweight='bold')
        if model_info: ax.text(0.5,1.10,model_info,transform=ax.transAxes,ha='center',fontsize=8,color='dimgray')
        fig.tight_layout(); plt.show()

# %%
scores,automl_results,bt,task=load_scores(AUTOML_TASK_ID); df_base,cfg=load_plot_base(EQUIPMENT_ID)
MODEL_INFO=model_info_str(bt); tr=bt['trial']; rs=bt['results']
print('Task:',task.name,'| status:',task.get_status(),'| trials:',len(automl_results))
print(MODEL_INFO)
print('scores:',scores.index.min(),'->',scores.index.max())
# Out:
# Task: automl-b6511502a-v2-win3-20-full | status: completed | trials: 3603
# Modelo AutoML: LSTM / baseline / p99.9 / debounce 1  ·  pré-falha 100% @ FP 0.9%
# scores: 2022-05-22 17:40:00 -> 2023-05-13 14:35:00

# %% [markdown]
# ## Ranking (top 10) — com FP held-out

# %%
cols=[x for x in ['model','preset','threshold_percentile','debounce_consecutive','prefailure_alert_rate','normal_alert_rate','val_fp_rate_heldout','composite_score'] if x in automl_results.columns]
fmt={k:'{:.2%}' for k in ['prefailure_alert_rate','normal_alert_rate','val_fp_rate_heldout']}; fmt['composite_score']='{:.4f}'; fmt['threshold_percentile']='{:.1f}'
sty=automl_results[cols].head(10).style.format({k:v for k,v in fmt.items() if k in cols})
if 'prefailure_alert_rate' in cols: sty=sty.background_gradient(subset=['prefailure_alert_rate'],cmap='Greens')
if 'val_fp_rate_heldout' in cols: sty=sty.background_gradient(subset=['val_fp_rate_heldout'],cmap='Reds_r')
display(sty)
if 'val_fp_rate_heldout' in automl_results.columns:
    print('Compare normal_alert_rate (in-sample) vs val_fp_rate_heldout (held-out, número honesto).')
# Out:
# <style type="text/css">
# #T_178d6_row0_col4, #T_178d6_row1_col4, #T_178d6_row2_col4, #T_178d6_row3_col4, #T_178d6_row4_col4, #T_178d6_row5_col4, #T_178d6_row6_col4, #T_178d6_row7_col4, #T_178d6_row8_col4, #T_178d6_row9_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_178d6_row0_col6 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_178d6_row1_col6 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_178d6_row2_col6 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_178d6_row3_col6 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_178d6_row4_col6 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_178d6_row5_col6 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_178d6_row6_col6 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_178d6_row7_col6 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_178d6_row8_col6 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_178d6_row9_col6 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_178d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_178d6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_178d6_level0_col1" class="col_heading level0 col1" >preset</th>
#       <th id="T_178d6_level0_col2" class="col_heading level0 col2" >threshold_percentile</th>
#       <th id="T_178d6_level0_col3" class="col_heading level0 col3" >debounce_consecutive</th>
#       <th id="T_178d6_level0_col4" class="col_heading level0 col4" >prefailure_alert_rate</th>
#       <th id="T_178d6_level0_col5" class="col_heading level0 col5" >normal_alert_rate</th>
#       <th id="T_178d6_level0_col6" class="col_heading level0 col6" >val_fp_rate_heldout</th>
#       <th id="T_178d6_level0_col7" class="col_heading level0 col7" >composite_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_178d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_178d6_row0_col0" class="data row0 col0" >vae</td>
#       <td id="T_178d6_row0_col1" class="data row0 col1" >baseline</td>
#       <td id="T_178d6_row0_col2" class="data row0 col2" >97.5</td>
#       <td id="T_178d6_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_178d6_row0_col4" class="data row0 col4" >100.00%</td>
#       <td id="T_178d6_row0_col5" class="data row0 col5" >0.24%</td>
#       <td id="T_178d6_row0_col6" class="data row0 col6" >0.48%</td>
#       <td id="T_178d6_row0_col7" class="data row0 col7" >0.9976</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_178d6_row1_col0" class="data row1 col0" >vae</td>
#       <td id="T_178d6_row1_col1" class="data row1 col1" >baseline</td>
#       <td id="T_178d6_row1_col2" class="data row1 col2" >97.5</td>
#       <td id="T_178d6_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_178d6_row1_col4" class="data row1 col4" >100.00%</td>
#       <td id="T_178d6_row1_col5" class="data row1 col5" >0.28%</td>
#       <td id="T_178d6_row1_col6" class="data row1 col6" >0.18%</td>
#       <td id="T_178d6_row1_col7" class="data row1 col7" >0.9972</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_178d6_row2_col0" class="data row2 col0" >vae</td>
#       <td id="T_178d6_row2_col1" class="data row2 col1" >baseline</td>
#       <td id="T_178d6_row2_col2" class="data row2 col2" >97.5</td>
#       <td id="T_178d6_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_178d6_row2_col4" class="data row2 col4" >100.00%</td>
#       <td id="T_178d6_row2_col5" class="data row2 col5" >0.33%</td>
#       <td id="T_178d6_row2_col6" class="data row2 col6" >0.40%</td>
#       <td id="T_178d6_row2_col7" class="data row2 col7" >0.9967</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_178d6_row3_col0" class="data row3 col0" >vae</td>
#       <td id="T_178d6_row3_col1" class="data row3 col1" >baseline</td>
#       <td id="T_178d6_row3_col2" class="data row3 col2" >97.5</td>
#       <td id="T_178d6_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_178d6_row3_col4" class="data row3 col4" >100.00%</td>
#       <td id="T_178d6_row3_col5" class="data row3 col5" >0.40%</td>
#       <td id="T_178d6_row3_col6" class="data row3 col6" >0.23%</td>
#       <td id="T_178d6_row3_col7" class="data row3 col7" >0.9960</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_178d6_row4_col0" class="data row4 col0" >vae</td>
#       <td id="T_178d6_row4_col1" class="data row4 col1" >baseline</td>
#       <td id="T_178d6_row4_col2" class="data row4 col2" >97.5</td>
#       <td id="T_178d6_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_178d6_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_178d6_row4_col5" class="data row4 col5" >0.41%</td>
#       <td id="T_178d6_row4_col6" class="data row4 col6" >1.42%</td>
#       <td id="T_178d6_row4_col7" class="data row4 col7" >0.9959</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_178d6_row5_col0" class="data row5 col0" >vae</td>
#       <td id="T_178d6_row5_col1" class="data row5 col1" >baseline</td>
#       <td id="T_178d6_row5_col2" class="data row5 col2" >97.5</td>
#       <td id="T_178d6_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_178d6_row5_col4" class="data row5 col4" >100.00%</td>
#       <td id="T_178d6_row5_col5" class="data row5 col5" >0.41%</td>
#       <td id="T_178d6_row5_col6" class="data row5 col6" >0.80%</td>
#       <td id="T_178d6_row5_col7" class="data row5 col7" >0.9959</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_178d6_row6_col0" class="data row6 col0" >vae</td>
#       <td id="T_178d6_row6_col1" class="data row6 col1" >baseline</td>
#       <td id="T_178d6_row6_col2" class="data row6 col2" >97.5</td>
#       <td id="T_178d6_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_178d6_row6_col4" class="data row6 col4" >100.00%</td>
#       <td id="T_178d6_row6_col5" class="data row6 col5" >0.48%</td>
#       <td id="T_178d6_row6_col6" class="data row6 col6" >1.65%</td>
#       <td id="T_178d6_row6_col7" class="data row6 col7" >0.9952</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_178d6_row7_col0" class="data row7 col0" >vae</td>
#       <td id="T_178d6_row7_col1" class="data row7 col1" >baseline</td>
#       <td id="T_178d6_row7_col2" class="data row7 col2" >97.5</td>
#       <td id="T_178d6_row7_col3" class="data row7 col3" >6</td>
#       <td id="T_178d6_row7_col4" class="data row7 col4" >100.00%</td>
#       <td id="T_178d6_row7_col5" class="data row7 col5" >0.56%</td>
#       <td id="T_178d6_row7_col6" class="data row7 col6" >0.31%</td>
#       <td id="T_178d6_row7_col7" class="data row7 col7" >0.9944</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_178d6_row8_col0" class="data row8 col0" >vae</td>
#       <td id="T_178d6_row8_col1" class="data row8 col1" >baseline</td>
#       <td id="T_178d6_row8_col2" class="data row8 col2" >97.5</td>
#       <td id="T_178d6_row8_col3" class="data row8 col3" >6</td>
#       <td id="T_178d6_row8_col4" class="data row8 col4" >100.00%</td>
#       <td id="T_178d6_row8_col5" class="data row8 col5" >0.65%</td>
#       <td id="T_178d6_row8_col6" class="data row8 col6" >0.26%</td>
#       <td id="T_178d6_row8_col7" class="data row8 col7" >0.9935</td>
#     </tr>
#     <tr>
#       <th id="T_178d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_178d6_row9_col0" class="data row9 col0" >vae</td>
#       <td id="T_178d6_row9_col1" class="data row9 col1" >baseline</td>
#       <td id="T_178d6_row9_col2" class="data row9 col2" >97.5</td>
#       <td id="T_178d6_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_178d6_row9_col4" class="data row9 col4" >100.00%</td>
#       <td id="T_178d6_row9_col5"
# Compare normal_alert_rate (in-sample) vs val_fp_rate_heldout (held-out, número honesto).

# %% [markdown]
# ## Ajuste de sensibilidade

# %%
_e=scores['reconstruction_error']; _ne=EVENT_TS_F1-pd.Timedelta(days=NORMAL_END_DAYS); _ps=EVENT_TS_F1-pd.Timedelta(days=PREFAILURE_DAYS)
_mn=scores.index<_ne; _mp=(scores.index>=_ps)&(scores.index<EVENT_TS_F1); _mpost=scores.index>=EVENT_TS_F1
def _deb(f,k,n): return (f.astype(int).rolling(n,min_periods=n).sum()>=k).fillna(False) if n>1 else f.astype(bool)
rows=[]
for p in [99.0,99.5,99.7,99.9]:
    thr=float(np.percentile(_e[_mn].values,p))
    for (k,n) in [(1,1),(4,6),(6,8)]:
        fl=_deb(_e>thr,k,n)
        rows.append({'percentil':p,'debounce':f'{k}/{n}','threshold':thr,'normal_FP':fl[_mn].mean(),'prefalha':fl[_mp].mean(),'pos':int(fl[_mpost].sum())})
g=pd.DataFrame(rows)
display(g.style.format({'threshold':'{:.5f}','normal_FP':'{:.2%}','prefalha':'{:.0%}'}).background_gradient(subset=['normal_FP'],cmap='Reds_r').background_gradient(subset=['prefalha'],cmap='Greens'))
TUNE_PERCENTILE=99.7; TUNE_K,TUNE_N=10,12
selected_threshold=float(np.percentile(_e[_mn].values,TUNE_PERCENTILE)); selected_k,selected_n=TUNE_K,TUNE_N
threshold_label=f'Limiar p{TUNE_PERCENTILE}+deb{TUNE_K}/{TUNE_N}'; flags=persistence_filter(_e>selected_threshold,selected_k,selected_n)
print(f'{threshold_label}: prefalha={flags[_mp].mean():.0%} normal_FP={flags[_mn].mean():.2%} (alertas começo da série/normal={int(flags[_mn].sum())})')
# Out:
# <style type="text/css">
# #T_9af8f_row0_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_9af8f_row0_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9af8f_row1_col3 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_9af8f_row1_col4 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_9af8f_row2_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_9af8f_row2_col4 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_9af8f_row3_col3 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_9af8f_row3_col4 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_9af8f_row4_col3 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_9af8f_row4_col4 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_9af8f_row5_col3 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_9af8f_row5_col4 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_9af8f_row6_col3 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_9af8f_row6_col4 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_9af8f_row7_col3 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_9af8f_row7_col4 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_9af8f_row8_col3 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_9af8f_row8_col4 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_9af8f_row9_col3 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_9af8f_row9_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_9af8f_row10_col3 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_9af8f_row10_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_9af8f_row11_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9af8f_row11_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_9af8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9af8f_level0_col0" class="col_heading level0 col0" >percentil</th>
#       <th id="T_9af8f_level0_col1" class="col_heading level0 col1" >debounce</th>
#       <th id="T_9af8f_level0_col2" class="col_heading level0 col2" >threshold</th>
#       <th id="T_9af8f_level0_col3" class="col_heading level0 col3" >normal_FP</th>
#       <th id="T_9af8f_level0_col4" class="col_heading level0 col4" >prefalha</th>
#       <th id="T_9af8f_level0_col5" class="col_heading level0 col5" >pos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9af8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9af8f_row0_col0" class="data row0 col0" >99.000000</td>
#       <td id="T_9af8f_row0_col1" class="data row0 col1" >1/1</td>
#       <td id="T_9af8f_row0_col2" class="data row0 col2" >1.82296</td>
#       <td id="T_9af8f_row0_col3" class="data row0 col3" >1.00%</td>
#       <td id="T_9af8f_row0_col4" class="data row0 col4" >94%</td>
#       <td id="T_9af8f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9af8f_row1_col0" class="data row1 col0" >99.000000</td>
#       <td id="T_9af8f_row1_col1" class="data row1 col1" >4/6</td>
#       <td id="T_9af8f_row1_col2" class="data row1 col2" >1.82296</td>
#       <td id="T_9af8f_row1_col3" class="data row1 col3" >0.92%</td>
#       <td id="T_9af8f_row1_col4" class="data row1 col4" >93%</td>
#       <td id="T_9af8f_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9af8f_row2_col0" class="data row2 col0" >99.000000</td>
#       <td id="T_9af8f_row2_col1" class="data row2 col1" >6/8</td>
#       <td id="T_9af8f_row2_col2" class="data row2 col2" >1.82296</td>
#       <td id="T_9af8f_row2_col3" class="data row2 col3" >0.85%</td>
#       <td id="T_9af8f_row2_col4" class="data row2 col4" >91%</td>
#       <td id="T_9af8f_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9af8f_row3_col0" class="data row3 col0" >99.500000</td>
#       <td id="T_9af8f_row3_col1" class="data row3 col1" >1/1</td>
#       <td id="T_9af8f_row3_col2" class="data row3 col2" >2.60784</td>
#       <td id="T_9af8f_row3_col3" class="data row3 col3" >0.50%</td>
#       <td id="T_9af8f_row3_col4" class="data row3 col4" >75%</td>
#       <td id="T_9af8f_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9af8f_row4_col0" class="data row4 col0" >99.500000</td>
#       <td id="T_9af8f_row4_col1" class="data row4 col1" >4/6</td>
#       <td id="T_9af8f_row4_col2" class="data row4 col2" >2.60784</td>
#       <td id="T_9af8f_row4_col3" class="data row4 col3" >0.45%</td>
#       <td id="T_9af8f_row4_col4" class="data row4 col4" >74%</td>
#       <td id="T_9af8f_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9af8f_row5_col0" class="data row5 col0" >99.500000</td>
#       <td id="T_9af8f_row5_col1" class="data row5 col1" >6/8</td>
#       <td id="T_9af8f_row5_col2" class="data row5 col2" >2.60784</td>
#       <td id="T_9af8f_row5_col3" class="data row5 col3" >0.38%</td>
#       <td id="T_9af8f_row5_col4" class="data row5 col4" >73%</td>
#       <td id="T_9af8f_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9af8f_row6_col0" class="data row6 col0" >99.700000</td>
#       <td id="T_9af8f_row6_col1" class="data row6 col1" >1/1</td>
#       <td id="T_9af8f_row6_col2" class="data row6 col2" >3.55666</td>
#       <td id="T_9af8f_row6_col3" class="data row6 col3" >0.30%</td>
#       <td id="T_9af8f_row6_col4" class="data row6 col4" >55%</td>
#       <td id="T_9af8f_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9af8f_row7_col0" class="data row7 col0" >99.700000</td>
#       <td id="T_9af8f_row7_col1" class="data row7 col1" >4/6</td>
#       <td id="T_9af8f_row7_col2" class="data row7 col2" >3.55666</td>
#       <td id="T_9af8f_row7_col3" class="data row7 col3" >0.27%</td>
#       <td id="T_9af8f_row7_col4" class="data row7 col4" >54%</td>
#       <td id="T_9af8f_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9af8f_row8_col0" class="data row8 col0" >99.700000</td>
#       <td id="T_9af8f_row8_col1" class="data row8 col1" >6/8</td>
#       <td id="T_9af8f_row8_col2" class="data row8 col2" >3.55666</td>
#       <td id="T_9af8f_row8_col3" class="data row8 col3" >0.24%</td>
#       <td id="T_9af8f_row8_col4" class="data row8 col4" >52%</td>
#       <td id="T_9af8f_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9af8f_row9_col0" class="data row9 col0" >99.900000</td>
#       <td id="T_9af8f_row9_col1" class="data row9 col1" >1/1</td>
#       <td id="T_9af8f_row9_col2" class="data row9 col2" >7.66194</td>
#       <td id="T_9af8f_row9_col3" class="data row9 col3" >0.10%</td>
#       <td id="T_9af8f_row9_col4" class="data row9 col4" >6%</td>
#       <td id="T_9af8f_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9af8f_row10_col0" class="data row10 col0" >99.900000</td>
#       <td id="T_9af8f_row10_col1" class="data row10 col1" >4/6</td>
#       <td id="T_9af8f_row10_col2" class="data row10 col2" >7.66194</td>
#       <td id="T_9af8f_row10_col3" class="data row10 col3" >0.09%</td>
#       <td id="T_9af8f_row10_col4" class="data row10 col4" >6%</td>
#       <td id="T_9af8f_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9af8f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9af8f_row11_col0" class="data row11 col0" >99.900000</td>
# Limiar p99.7+deb10/12: prefalha=49% normal_FP=0.19% (alertas começo da série/normal=65)

# %% [markdown]
# ## Zoom antes da falha (com score; modelo no topo)

# %%
z=EVENT_TS_F1-pd.Timedelta(days=10); dfw=df_base.loc[z:EVENT_TS_F1]; sw=scores.loc[z:EVENT_TS_F1]
common=dfw.index.intersection(sw.index); dfw,sw=dfw.loc[common],sw.loc[common]
sensors=[s for s in KEY_SENSORS if s in dfw.columns]
plot_separated(dfw,sw,sensors,selected_threshold,selected_k,selected_n,EVENT_TS_F1,EVENT_LABEL_F1,PREFAILURE_DAYS,
   title_prefix=f'{EQUIPMENT_ID} — 10d antes da falha',tag='zoom',threshold_label=threshold_label,model_info=MODEL_INFO)

# %% [markdown]
# ## Série completa

# %%
plt.style.use('seaborn-v0_8-whitegrid'); fig,ax=plt.subplots(figsize=(14,3.6)); y=_e
fl=persistence_filter(y>selected_threshold,selected_k,selected_n)
ax.plot(scores.index,y,color='purple',lw=0.6,alpha=0.5,label='Score'); ax.axhline(selected_threshold,color='red',ls='--',lw=1.2,label=threshold_label)
idx=scores.index[fl]; ax.scatter(idx,y[idx],s=12,color='red',alpha=0.6,zorder=4,label=f'Alertas ({len(idx)})')
ax.axvline(EVENT_TS_F1,color='orange',ls='--',lw=1.5,label=EVENT_LABEL_F1)
ax.set_ylabel('Score'); ax.set_xlabel('Tempo'); ax.legend(loc='upper left',fontsize=8,ncol=3)
ax.set_title(f'{EQUIPMENT_ID} — Série completa',fontweight='bold'); ax.text(0.5,1.12,MODEL_INFO,transform=ax.transAxes,ha='center',fontsize=8,color='dimgray')
fig.tight_layout(); plt.show(); print(f'alertas no começo (normal,<-{NORMAL_END_DAYS}d): {int(fl[_mn].sum())}')
# Out:
# alertas no começo (normal,<-20d): 65

# %% [markdown]
# ---
# ## Parte 2 — Ensemble por VOTAÇÃO (dense + LSTM)
#
# Combina o modelo **dense** (task antiga d8a064a4, score mais limpo) com o **LSTM** (este v2 full).
# **AND (consenso)** = alerta só quando os dois concordam → FP mínimo. **OR / score combinado** =
# alerta se qualquer um dispara → detecção máxima.

# %%
# Carrega o dense e alinha com o LSTM (já em )
dense=Task.get_task(task_id="d8a064a4c48a47d0a37ea69a870064a9").artifacts["best_full_scores"].get()
dense.index=pd.to_datetime(dense.index); dense=dense.sort_index()
idx=scores.index.intersection(dense.index); L=scores.loc[idx]; D=dense.loc[idx]
mn=idx<EVENT_TS_F1-pd.Timedelta(days=NORMAL_END_DAYS); mp=(idx>=EVENT_TS_F1-pd.Timedelta(days=PREFAILURE_DAYS))&(idx<EVENT_TS_F1)
def alert(s,p,k,n):
    thr=np.percentile(s["reconstruction_error"][mn].values,p)
    return persistence_filter(s["reconstruction_error"]>thr,k,n)
dA=alert(D,99.5,8,10); lA=alert(L,99.5,6,8)
AND=dA&lA; OR=dA|lA
def zc(s):
    e=s["reconstruction_error"]; return (e-e[mn].mean())/(e[mn].std()+1e-9)
comb=(zc(D)+zc(L))/2; cthr=np.percentile(comb[mn].values,99.5); combA=persistence_filter(comb>cthr,6,8)
print("%-22s | %-11s %-10s" % ("esquema","detecção3d","FP_normal"))
for nm,fl in [("dense",dA),("LSTM",lA),("AND (consenso, min FP)",AND),("OR (qualquer)",OR),("score combinado (z)",combA)]:
    print("%-22s | %-11s %-10s" % (nm, f"{fl[mp].mean():.0%}", f"{fl[mn].mean():.2%}"))
may06=(idx>=pd.Timestamp("2023-05-06"))&(idx<pd.Timestamp("2023-05-07"))
print("\nFP em 06/mai: LSTM=%d, AND consenso=%d (o dense discorda do LSTM -> consenso limpa)."%(int(lA[may06].sum()),int(AND[may06].sum())))
print("RECOMENDADO p/ FP minimo: AND consenso (60%% @ 0%% FP). Para deteccao maxima: combinado (91%% @ 0,36%%).")
# Out:
# esquema                | detecção3d  FP_normal
# dense                  | 78%         0.12%
# LSTM                   | 73%         0.38%
# AND (consenso, min FP) | 60%         0.00%
# OR (qualquer)          | 91%         0.51%
# score combinado (z)    | 91%         0.36%
#
# FP em 06/mai: LSTM=55, AND consenso=2 (o dense discorda do LSTM -> consenso limpa).
# RECOMENDADO p/ FP minimo: AND consenso (60%% @ 0%% FP). Para deteccao maxima: combinado (91%% @ 0,36%%).

# %%
# Score combinado (média z) — últimos 10 dias, com os 3 esquemas
plt.style.use("seaborn-v0_8-whitegrid"); z10=EVENT_TS_F1-pd.Timedelta(days=10)
w=comb.loc[z10:EVENT_TS_F1]; fig,ax=plt.subplots(figsize=(14,3.4))
ax.plot(w.index,w.values,color="darkviolet",lw=0.9,alpha=0.7,label="score combinado (média z)")
ax.axhline(cthr,color="red",ls="--",lw=1.2,label="limiar combinado")
for nm,fl,col in [("AND consenso",AND,"green"),("OR",OR,"orange")]:
    a=fl.loc[z10:EVENT_TS_F1]; ai=w.index[a.values]
    if len(ai): ax.scatter(ai,w.reindex(ai),s=18,color=col,label=nm,zorder=4,alpha=0.7)
ax.axvline(EVENT_TS_F1,color="orange",ls="--",lw=1.5,label=EVENT_LABEL_F1)
ax.set_ylabel("score combinado (z)"); ax.set_xlabel("Tempo"); ax.legend(loc="upper left",fontsize=8,ncol=2)
ax.set_title(f"{EQUIPMENT_ID} — Ensemble dense+LSTM (10 dias antes da falha)",fontweight="bold"); fig.tight_layout(); plt.show()
